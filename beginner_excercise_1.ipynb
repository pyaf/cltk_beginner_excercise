# %%
import cltk

# %%
from cltk.corpus.utils.importer import CorpusImporter

# %%
import os

# %%
corpor = CorpusImporter("hindi")

# %%
corpor.list_corpora
# Out:
# ['hindi_text_ltrc']

# %%
base_dir = os.path.dirname(os.path.abspath('__file__'))
print(base_dir)
# Out:
# /media/ags/DATA/GSOC/cltk_beginner_excercise

# %%
corpora_dir = os.path.join(base_dir, 'hindi_text_ltrc/')
print(corpora_dir)
# Out:
# /media/ags/DATA/GSOC/cltk_beginner_excercise/hindi_text_ltrc/
